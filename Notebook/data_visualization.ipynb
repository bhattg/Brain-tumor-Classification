# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import os
from tqdm import tqdm_notebook as tqdm

from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets
from sklearn.manifold import TSNE
#from Modules.visualizer import pcaVisualize2d
from sklearn import svm

# %%
root = "C:\\Users\\Chahat\\Desktop\\dl\\data"

# %%
x_train = np.load(os.path.join(root, "x_train.npy"))
y_train = np.load(os.path.join(root, "y_train.npy"))
s_train = np.load(os.path.join(root, "s_train.npy"))

# %%
plt.imshow(x_train[70,:,:])
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
def pcaVisualize2d(x_train, s_train):
    pca = decomposition.PCA(n_components=2)
    x_train2 = x_train.reshape(x_train.shape[0], -1)
    pca.fit(x_train2)
    x_train2 = pca.transform(x_train2)
    plt.figure()
    plt.scatter(x_train2[:,0],x_train2[:,1],c = np.arange(120), marker=".")
        
def pcaVisualize3d(x_train, s_train):
    pca = decomposition.PCA(n_components=3)
    x_train2 = x_train.reshape(x_train.shape[0], -1)
    pca.fit(x_train2)
    x_train2 = pca.transform(x_train2)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection = "3d")
    ax.scatter(x_train2[:, 0], x_train2[:, 1], x_train2[:, 2], c = s_train , marker = ".")
    ax.set_xlabel("TEST1")
    ax.set_ylabel("TEST2")
    ax.set_zlabel("TEST3")
    
def tsne2d(x_train, s_train):
    x_train2 = x_train.reshape(x_train.shape[0], -1)
    X_embedded = TSNE(n_components=2).fit_transform(x_train2)
    plt.figure()
    plt.scatter(X_embedded[:,0],X_embedded[:,1],c = s_train, marker=".")
    
    
def tsne3d(x_train,s_train):
    x_train2 = x_train.reshape(x_train.shape[0], -1)
    X_embedded = TSNE(n_components=3).fit_transform(x_train2)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection = "3d")
    ax.scatter(X_embedded[:, 0], X_embedded[:, 1], X_embedded[:, 2], c = s_train , marker = ".")
    ax.set_xlabel("TEST1")
    ax.set_ylabel("TEST2")
    ax.set_zlabel("TEST3")

# %%
x_me = x_train[120:240,:,:]
s_me = s_train[120:240]

# %%
tsne2d(x_me,s_me)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
pcaVisualize2d(x_me, s_me)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
pcaVisualize2d(x_train, s_train)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pcaVisualize3d(x_train, s_train)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_train_new = x_train[:200]
s_train_new = s_train[:200]

# %%
tsne2d(x_train_new,s_train_new)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tsne3d(x_train_new,s_train_new)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_train2 = x_train.reshape(x_train.shape[0], -1)

# %%
from sklearn import svm

def svm():
    clf = svm.SVC(gamma='scale')
    clf.fit(x_train_fake, s_train_fake)  
    print(clf.score(x_train_fake, s_train_fake))
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# # Visualize Data

# %%
path = "C:\\Users\\Chahat\\Desktop\\daata"
x_path = os.path.join(path, "Train_x.npy")
y_path = os.path.join(path, "Train_y.npy")
x_train = np.load(x_path)
y_train = np.load(y_path)
print(x_train.shape)
print(y_train.shape)
# Out:
# (38223, 240, 240)
# (38223, 240, 240)

# %%
x_data = x_train[:1000,:,:]
y_data = y_train[:1000,:,:]

# %%
print(x_data.shape)
print(y_data.shape)
# Out:
# (1000, 240, 240)
# (1000, 240, 240)

# %%
s_data = y_data.sum(axis = 1).sum(axis = 1) > 0

# %%
print(s_data.shape)
# Out:
# (1000,)

# %%
pcaVisualize2d(x_data, s_data)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
pcaVisualize3d(x_data, s_data)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
tsne2d(x_data,s_data)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
tsne3d(x_data,s_data)
